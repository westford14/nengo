# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import nengo
# %load_ext nengo.ipynb
from nengo.dists import Uniform
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="47644180" href="javascript:toggle_input_47644180()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_47644180;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_47644180 = document.getElementById("47644180");
#                 var cell = link_47644180;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_47644180;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_47644180 = cell.children[i];
#                 }
#                 input_47644180.style.display = "none"; // hide
#
#                 toggle_input_47644180 = function() {
#                     if (input_47644180.style.display == "none") {
#                         input_47644180.style.display = ""; // show
#                         link_47644180.innerHTML = "Hide Input";
#                     } else {
#                         input_47644180.style.display = "none"; // hide
#                         link_47644180.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_47644180 = $("a[id='47644180']");
#                 var cell_47644180 = link_47644180.parents("div.cell:first");
#                 var input_47644180 = cell_47644180.children("div.input");
#                 input_47644180.hide();
#
#                 toggle_input_47644180 = function() {
#                     if (input_47644180.is(':hidden')) {
#                         input_47644180.slideDown();
#                         link_47644180[0].innerHTML = "Hide Input";
#                     } else {
#                         input_47644180.slideUp();
#                         link_47644180[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Introduction
# The Neural Engineering Framework (NEF) is the set of theoretical methods that are used in Nengo for constructing neural models.  The NEF is based on <a href="http://www.amazon.com/gp/product/0262550601">Eliasmith & Anderson's (2003) book</a> from MIT Press. This notebook introduces the three main principles discussed in that book and implemented in Nengo.

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals through their spiking responses. A signal is a vector of real numbers of arbitrary length. This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1228407945" href="javascript:toggle_input_1228407945()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1228407945;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1228407945 = document.getElementById("1228407945");
#                 var cell = link_1228407945;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1228407945;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1228407945 = cell.children[i];
#                 }
#                 input_1228407945.style.display = "none"; // hide
#
#                 toggle_input_1228407945 = function() {
#                     if (input_1228407945.style.display == "none") {
#                         input_1228407945.style.display = ""; // show
#                         link_1228407945.innerHTML = "Hide Input";
#                     } else {
#                         input_1228407945.style.display = "none"; // hide
#                         link_1228407945.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1228407945 = $("a[id='1228407945']");
#                 var cell_1228407945 = link_1228407945.parents("div.cell:first");
#                 var input_1228407945 = cell_1228407945.children("div.input");
#                 input_1228407945.hide();
#
#                 toggle_input_1228407945 = function() {
#                     if (input_1228407945.is(':hidden')) {
#                         input_1228407945.slideDown();
#                         link_1228407945[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1228407945.slideUp();
#                         link_1228407945[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F (current-frequency) curve, if you're familiar with that).
#
# The tuning curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1144894278" href="javascript:toggle_input_1144894278()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1144894278;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1144894278 = document.getElementById("1144894278");
#                 var cell = link_1144894278;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1144894278;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1144894278 = cell.children[i];
#                 }
#                 input_1144894278.style.display = "none"; // hide
#
#                 toggle_input_1144894278 = function() {
#                     if (input_1144894278.style.display == "none") {
#                         input_1144894278.style.display = ""; // show
#                         link_1144894278.innerHTML = "Hide Input";
#                     } else {
#                         input_1144894278.style.display = "none"; // hide
#                         link_1144894278.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1144894278 = $("a[id='1144894278']");
#                 var cell_1144894278 = link_1144894278.parents("div.cell:first");
#                 var input_1144894278 = cell_1144894278.children("div.input");
#                 input_1144894278.hide();
#
#                 toggle_input_1144894278 = function() {
#                     if (input_1144894278.is(':hidden')) {
#                         input_1144894278.slideDown();
#                         link_1144894278[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1144894278.slideUp();
#                         link_1144894278[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="512689603" href="javascript:toggle_input_512689603()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_512689603;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_512689603 = document.getElementById("512689603");
#                 var cell = link_512689603;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_512689603;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_512689603 = cell.children[i];
#                 }
#                 input_512689603.style.display = "none"; // hide
#
#                 toggle_input_512689603 = function() {
#                     if (input_512689603.style.display == "none") {
#                         input_512689603.style.display = ""; // show
#                         link_512689603.innerHTML = "Hide Input";
#                     } else {
#                         input_512689603.style.display = "none"; // hide
#                         link_512689603.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_512689603 = $("a[id='512689603']");
#                 var cell_512689603 = link_512689603.parents("div.cell:first");
#                 var input_512689603 = cell_512689603.children("div.input");
#                 input_512689603.hide();
#
#                 toggle_input_512689603 = function() {
#                     if (input_512689603.is(':hidden')) {
#                         input_512689603.slideDown();
#                         link_512689603[0].innerHTML = "Hide Input";
#                     } else {
#                         input_512689603.slideUp();
#                         link_512689603[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded by decoding the pattern of spikes. To do this, we first filter the spike train with a temporal filter that accounts for postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons));
hide_input()
# Out:
#         <a id="1154826988" href="javascript:toggle_input_1154826988()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1154826988;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1154826988 = document.getElementById("1154826988");
#                 var cell = link_1154826988;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1154826988;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1154826988 = cell.children[i];
#                 }
#                 input_1154826988.style.display = "none"; // hide
#
#                 toggle_input_1154826988 = function() {
#                     if (input_1154826988.style.display == "none") {
#                         input_1154826988.style.display = ""; // show
#                         link_1154826988.innerHTML = "Hide Input";
#                     } else {
#                         input_1154826988.style.display = "none"; // hide
#                         link_1154826988.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1154826988 = $("a[id='1154826988']");
#                 var cell_1154826988 = link_1154826988.parents("div.cell:first");
#                 var input_1154826988 = cell_1154826988.children("div.input");
#                 input_1154826988.hide();
#
#                 toggle_input_1154826988 = function() {
#                     if (input_1154826988.is(':hidden')) {
#                         input_1154826988.slideDown();
#                         link_1154826988[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1154826988.slideUp();
#                         link_1154826988[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together to give an estimate of the input based on the spikes.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1127185986" href="javascript:toggle_input_1127185986()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1127185986;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1127185986 = document.getElementById("1127185986");
#                 var cell = link_1127185986;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1127185986;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1127185986 = cell.children[i];
#                 }
#                 input_1127185986.style.display = "none"; // hide
#
#                 toggle_input_1127185986 = function() {
#                     if (input_1127185986.style.display == "none") {
#                         input_1127185986.style.display = ""; // show
#                         link_1127185986.innerHTML = "Hide Input";
#                     } else {
#                         input_1127185986.style.display = "none"; // hide
#                         link_1127185986.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1127185986 = $("a[id='1127185986']");
#                 var cell_1127185986 = link_1127185986.parents("div.cell:first");
#                 var input_1127185986 = cell_1127185986.children("div.input");
#                 input_1127185986.hide();
#
#                 toggle_input_1127185986 = function() {
#                     if (input_1127185986.is(':hidden')) {
#                         input_1127185986.slideDown();
#                         link_1127185986[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1127185986.slideUp();
#                         link_1127185986[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="706210111" href="javascript:toggle_input_706210111()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_706210111;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_706210111 = document.getElementById("706210111");
#                 var cell = link_706210111;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_706210111;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_706210111 = cell.children[i];
#                 }
#                 input_706210111.style.display = "none"; // hide
#
#                 toggle_input_706210111 = function() {
#                     if (input_706210111.style.display == "none") {
#                         input_706210111.style.display = ""; // show
#                         link_706210111.innerHTML = "Hide Input";
#                     } else {
#                         input_706210111.style.display = "none"; // hide
#                         link_706210111.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_706210111 = $("a[id='706210111']");
#                 var cell_706210111 = link_706210111.parents("div.cell:first");
#                 var input_706210111 = cell_706210111.children("div.input");
#                 input_706210111.hide();
#
#                 toggle_input_706210111 = function() {
#                     if (input_706210111.is(':hidden')) {
#                         input_706210111.slideDown();
#                         link_706210111[0].innerHTML = "Hide Input";
#                     } else {
#                         input_706210111.slideUp();
#                         link_706210111[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.processes import WhiteSignal

model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1932948940" href="javascript:toggle_input_1932948940()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1932948940;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1932948940 = document.getElementById("1932948940");
#                 var cell = link_1932948940;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1932948940;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1932948940 = cell.children[i];
#                 }
#                 input_1932948940.style.display = "none"; // hide
#
#                 toggle_input_1932948940 = function() {
#                     if (input_1932948940.style.display == "none") {
#                         input_1932948940.style.display = ""; // show
#                         link_1932948940.innerHTML = "Hide Input";
#                     } else {
#                         input_1932948940.style.display = "none"; // hide
#                         link_1932948940.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1932948940 = $("a[id='1932948940']");
#                 var cell_1932948940 = link_1932948940.parents("div.cell:first");
#                 var input_1932948940 = cell_1932948940.children("div.input");
#                 input_1932948940.hide();
#
#                 toggle_input_1932948940 = function() {
#                     if (input_1932948940.is(':hidden')) {
#                         input_1932948940.slideDown();
#                         link_1932948940[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1932948940.slideUp();
#                         link_1932948940[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="2092693895" href="javascript:toggle_input_2092693895()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2092693895;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2092693895 = document.getElementById("2092693895");
#                 var cell = link_2092693895;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2092693895;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_2092693895 = cell.children[i];
#                 }
#                 input_2092693895.style.display = "none"; // hide
#
#                 toggle_input_2092693895 = function() {
#                     if (input_2092693895.style.display == "none") {
#                         input_2092693895.style.display = ""; // show
#                         link_2092693895.innerHTML = "Hide Input";
#                     } else {
#                         input_2092693895.style.display = "none"; // hide
#                         link_2092693895.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2092693895 = $("a[id='2092693895']");
#                 var cell_2092693895 = link_2092693895.parents("div.cell:first");
#                 var input_2092693895 = cell_2092693895.children("div.input");
#                 input_2092693895.hide();
#
#                 toggle_input_2092693895 = function() {
#                     if (input_2092693895.is(':hidden')) {
#                         input_2092693895.slideDown();
#                         link_2092693895[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2092693895.slideUp();
#                         link_2092693895[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes. We told Nengo to compute a new set of decoders that estimate the function $x^2$.
#
# In general, the transformation principle determines how we can decode spike trains to compute linear and nonlinear transformations of signals encoded in a population of neurons. We can then project those transformed signals into another population, and repeat the process.  Essentially, this provides a means of computing the neural connection weights to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="1316120591" href="javascript:toggle_input_1316120591()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1316120591;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1316120591 = document.getElementById("1316120591");
#                 var cell = link_1316120591;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1316120591;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1316120591 = cell.children[i];
#                 }
#                 input_1316120591.style.display = "none"; // hide
#
#                 toggle_input_1316120591 = function() {
#                     if (input_1316120591.style.display == "none") {
#                         input_1316120591.style.display = ""; // show
#                         link_1316120591.innerHTML = "Hide Input";
#                     } else {
#                         input_1316120591.style.display = "none"; // hide
#                         link_1316120591.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1316120591 = $("a[id='1316120591']");
#                 var cell_1316120591 = link_1316120591.parents("div.cell:first");
#                 var input_1316120591 = cell_1316120591.children("div.input");
#                 input_1316120591.hide();
#
#                 toggle_input_1316120591 = function() {
#                     if (input_1316120591.is(':hidden')) {
#                         input_1316120591.slideDown();
#                         link_1316120591[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1316120591.slideUp();
#                         link_1316120591[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights. Let us flip this sine wave upside down as it is transmitted between two populations (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
# /home/travis/build/nengo/nengo/nengo/builder/optimizer.py:636: UserWarning: Skipping some optimization steps because SciPy is not installed. Installing SciPy may result in faster simulations.
#   warnings.warn("Skipping some optimization steps because SciPy is "
#         <a id="1922360402" href="javascript:toggle_input_1922360402()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1922360402;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1922360402 = document.getElementById("1922360402");
#                 var cell = link_1922360402;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1922360402;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1922360402 = cell.children[i];
#                 }
#                 input_1922360402.style.display = "none"; // hide
#
#                 toggle_input_1922360402 = function() {
#                     if (input_1922360402.style.display == "none") {
#                         input_1922360402.style.display = ""; // show
#                         link_1922360402.innerHTML = "Hide Input";
#                     } else {
#                         input_1922360402.style.display = "none"; // hide
#                         link_1922360402.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1922360402 = $("a[id='1922360402']");
#                 var cell_1922360402 = link_1922360402.parents("div.cell:first");
#                 var input_1922360402 = cell_1922360402.children("div.input");
#                 input_1922360402.hide();
#
#                 toggle_input_1922360402 = function() {
#                     if (input_1922360402.is(':hidden')) {
#                         input_1922360402.slideDown();
#                         link_1922360402[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1922360402.slideUp();
#                         link_1922360402[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights. Let us add a third population connected to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron");
hide_input()
# Out:
#         <a id="942059113" href="javascript:toggle_input_942059113()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_942059113;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_942059113 = document.getElementById("942059113");
#                 var cell = link_942059113;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_942059113;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_942059113 = cell.children[i];
#                 }
#                 input_942059113.style.display = "none"; // hide
#
#                 toggle_input_942059113 = function() {
#                     if (input_942059113.style.display == "none") {
#                         input_942059113.style.display = ""; // show
#                         link_942059113.innerHTML = "Hide Input";
#                     } else {
#                         input_942059113.style.display = "none"; // hide
#                         link_942059113.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_942059113 = $("a[id='942059113']");
#                 var cell_942059113 = link_942059113.parents("div.cell:first");
#                 var input_942059113 = cell_942059113.children("div.input");
#                 input_942059113.hide();
#
#                 toggle_input_942059113 = function() {
#                     if (input_942059113.is(':hidden')) {
#                         input_942059113.slideDown();
#                         link_942059113[0].innerHTML = "Hide Input";
#                     } else {
#                         input_942059113.slideUp();
#                         link_942059113[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we have been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory or dynamic systems theory to brain models.  Nengo automatically translates from standard dynamical systems descriptions to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics, we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator implemented using this third principle. It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$');
hide_input()
# Out:
#         <a id="52133399" href="javascript:toggle_input_52133399()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_52133399;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_52133399 = document.getElementById("52133399");
#                 var cell = link_52133399;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_52133399;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_52133399 = cell.children[i];
#                 }
#                 input_52133399.style.display = "none"; // hide
#
#                 toggle_input_52133399 = function() {
#                     if (input_52133399.style.display == "none") {
#                         input_52133399.style.display = ""; // show
#                         link_52133399.innerHTML = "Hide Input";
#                     } else {
#                         input_52133399.style.display = "none"; // hide
#                         link_52133399.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_52133399 = $("a[id='52133399']");
#                 var cell_52133399 = link_52133399.parents("div.cell:first");
#                 var input_52133399 = cell_52133399.children("div.input");
#                 input_52133399.hide();
#
#                 toggle_input_52133399 = function() {
#                     if (input_52133399.is(':hidden')) {
#                         input_52133399.slideDown();
#                         link_52133399[0].innerHTML = "Hide Input";
#                     } else {
#                         input_52133399.slideUp();
#                         link_52133399[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
